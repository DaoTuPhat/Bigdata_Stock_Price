# %% [markdown]
# # Thực hiện đọc dữ liệu từ hdfs

# %% [markdown]
# Dữ liệu đã được lưu trữ trên hdfs, hiện tại ta cần sử dụng pyspark để đọc dữ liệu ra và xử lý. Cụm spark đã được bật, ta có thể xem thông tin của cả cụm trên web ui host post của spark-master là 0.0.0.0:8080 (truy cập qua localhost) hoặc 172.19.0.2:8080 (truy cập qua ip của container trong docker, xem thông tin bằng lệnh docker network inspect).

# %%
from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession
from IPython.display import Image

# %%
#Truy cập vào master của cụm tại địa chỉ 172.19.0.4:7077 với tên chương trình là Stock_price_analysis
spark = SparkSession.builder.master("spark://spark-master:7077").appName("Stock_price_analysis").getOrCreate()

# %% [markdown]
# Ta có thể  truy cập vào địa chỉ web ui của spark-master để xem thông tin của chương trình đang chạy

# %%
Image("spark_app.png")

# %% [markdown]
# Tiếp theo ta sẽ sử dụng spark session vừa tạo để truy cập vào hdfs và lấy dữ liệu ra để xử lý. Cụ thể ta sẽ truy cập vào địa chỉ của namenode trên hdfs là namenode:9000

# %% [markdown]
# # Một số phân tích cơ bản
#
# Ta lấy dữ liệu dataframe từ spark như thông thường.
#
# Ở đây ta so sánh dữ liệu chứng khoán của 5 công ty lớn:
#
# #### Vingroup (mã VIC)
#
# #### Vinhomes (mã VHM)
#
# #### Vietcombank (mã VCB)
#
# #### Vinamilk (mã VNM)
#
# #### Masan (mã MSN)

# %%
df_VIC = spark.read.format("csv").option("header", "true")\
.option("inferSchema", "true").load("hdfs://namenode:9000/user/root/datackvn/stock_market_data-VIC_2025-10-19.csv")

df_HPG = spark.read.format("csv").option("header", "true")\
.option("inferSchema", "true").load("hdfs://namenode:9000/user/root/datackvn/stock_market_data-HPG_2025-10-19.csv")

df_VCB = spark.read.format("csv").option("header", "true")\
.option("inferSchema", "true").load("hdfs://namenode:9000/user/root/datackvn/stock_market_data-VCB_2025-10-19.csv")

df_FPT = spark.read.format("csv").option("header", "true")\
.option("inferSchema", "true").load("hdfs://namenode:9000/user/root/datackvn/stock_market_data-FPT_2025-10-19.csv")

df_MSN = spark.read.format("csv").option("header", "true")\
.option("inferSchema", "true").load("hdfs://namenode:9000/user/root/datackvn/stock_market_data-MSN_2025-10-19.csv")

# %% [markdown]
# Sau khi lấy dữ liệu, ta thực hiện việc thêm cột Mean để tìm trung bình của mã chứng khoán trong ngày.
#
# Từ đó ta vẽ được biểu đồ để so sánh các mã chứng khoán.

# %%
from pyspark.sql.functions import year, expr

df_VICmean = df_VIC.withColumn("Mean", expr('(High+Low)/2'))
df_HPGmean = df_HPG.withColumn("Mean", expr('(High+Low)/2'))
df_VCBmean = df_VCB.withColumn("Mean", expr('(High+Low)/2'))
df_FPTmean = df_FPT.withColumn("Mean", expr('(High+Low)/2'))
df_MSNmean = df_MSN.withColumn("Mean", expr('(High+Low)/2'))

# %% [markdown]
# Để dễ sử dụng thư viện đồ thị matplotlib, ta chuyển các dữ liệu dataframes về dạng pandas.

# %%
df_VICmean = df_VICmean.toPandas()
df_HPGmean = df_HPGmean.toPandas()
df_VCBmean = df_VCBmean.toPandas()
df_FPTmean = df_FPTmean.toPandas()
df_MSNmean = df_MSNmean.toPandas()

# %% [markdown]
# Kết quả so sánh chỉ số trung bình trong ngày của các mã nói trên trong đồ thị

# %%
ax = df_VICmean.plot(x='Date', y='Mean', label='Vingroup', figsize=(16,6))
ax = df_HPGmean.plot(ax=ax, x='Date', y='Mean', label='Hòa Phát')
ax = df_VCBmean.plot(ax=ax, x='Date', y='Mean', label='Vietcombank')
ax = df_FPTmean.plot(ax=ax, x='Date', y='Mean', label='FPT')
ax = df_MSNmean.plot(ax=ax, x='Date', y='Mean', label='Masan')

# %% [markdown]
# Ta đánh giá sự thay đổi của các mã của các công ty Facebook, Alibaba và Zoom trên theo ngày (tính theo %) (Apple và Cloudfare ta không xét do thời gian quá lớn hoặc quá nhỏ)

# %%
df_VICmean['Change'] = (df_VICmean['Close']/df_VICmean['Close'].shift(1)) - 1
df_HPGmean['Change'] = (df_HPGmean['Close']/df_HPGmean['Close'].shift(1)) - 1
df_VCBmean['Change'] = (df_VCBmean['Close']/df_VCBmean['Close'].shift(1)) - 1
df_FPTmean['Change'] = (df_FPTmean['Close']/df_FPTmean['Close'].shift(1)) - 1
df_MSNmean['Change'] = (df_MSNmean['Close']/df_MSNmean['Close'].shift(1)) - 1

# %% [markdown]
# Sau đó, ta vẽ biểu đồ cột thể hiện sự thay đổi của các mã theo ngày

# %%
import matplotlib.pyplot as plt

df_VICmean['Change'].hist(bins=100, label='Vingroup',alpha=0.5)
df_HPGmean['Change'].hist(bins=100, label='Hòa Phát',alpha=0.5)
df_VCBmean['Change'].hist(bins=100, label='Vietcombank',alpha=0.5)
df_FPTmean['Change'].hist(bins=100, label='FPT',alpha=0.5)
df_MSNmean['Change'].hist(bins=100, label='Masan',alpha=0.5)

plt.legend()

# %% [markdown]
# Biểu đồ trên thể hiện sự biến động của từng mã. Số lượng gần 0 càng nhiều chứng tỏ là mã càng biến động ít và ngược lại.
#
# Ta vẽ biểu đồ đường để miêu tả rõ hơn điều đó

# %%
df_VICmean['Change'].plot(kind= 'kde', label = 'Vingroup')
df_HPGmean['Change'].plot(kind= 'kde', label = 'Hòa Phát')
df_VCBmean['Change'].plot(kind= 'kde', label = 'Vietcombank')
df_FPTmean['Change'].plot(kind= 'kde', label = 'FPT')
df_MSNmean['Change'].plot(kind= 'kde', label = 'Masan')

plt.legend()

# %% [markdown]
# Từ biểu đồ trên, ta thấy sự biến động của các mã đều gần giống với phân phối chuẩn có giá trị trung bình là 0.

# %% [markdown]
# # Dùng mô hình học máy để dự đoán tình hình chứng khoán

# %% [markdown]
# Trong phần này chúng em sẽ tính giá trị trung bình của cổ phiếu công ty Gabelli Equity Trust Inc (mã là GAB). Rồi sử dụng một mô hình học máy đơn giản để dự đoán giá cổ phiếu trung bình của công ty. Chúng em dùng các thông tin từ trước năm 2020 cho việc training và thông tin của năm 2020 cho việc testing.

# %%
df = spark.read.format("csv")\
.option("header", "true")\
.option("inferSchema", "true")\
.load("hdfs://namenode:9000/user/root/datackvn/stock_market_data-SAM_2025-10-19.csv")

# %%
# df = spark.read.format("csv")\
# .option("header", "true")\
# .option("inferSchema", "true")\
# .load("hdfs://namenode:9000/user/root/datack/stock_market_data-GAB_2020-12-15.csv")

# %%
df.show(5)
# Out:
# +----+----------+----+----+----+-----+
# | _c0|      Date|Open|High| Low|Close|
# +----+----------+----+----+----+-----+
# |6134|2025-10-17|6.94|7.05|6.89| 7.01|
# |6133|2025-10-16|6.82|7.05|6.82| 6.95|
# |6132|2025-10-15|6.98| 7.0| 6.8|  6.8|
# |6131|2025-10-14|7.52|7.54|6.95| 6.96|
# |6130|2025-10-13|7.51|7.53|7.36| 7.47|
# +----+----------+----+----+----+-----+
# only showing top 5 rows

# %%
from pyspark.sql.functions import expr, col, column

df = df.withColumn("Mean", expr('(High+Low)/2'))  #Thêm một cột giá trị mean ( được tính bằng trung bình của low và high

# %%
df.show(5)
# Out:
# +----+----------+----+----+----+-----+------------------+
# | _c0|      Date|Open|High| Low|Close|              Mean|
# +----+----------+----+----+----+-----+------------------+
# |6134|2025-10-17|6.94|7.05|6.89| 7.01|              6.97|
# |6133|2025-10-16|6.82|7.05|6.82| 6.95|6.9350000000000005|
# |6132|2025-10-15|6.98| 7.0| 6.8|  6.8|               6.9|
# |6131|2025-10-14|7.52|7.54|6.95| 6.96|             7.245|
# |6130|2025-10-13|7.51|7.53|7.36| 7.47|             7.445|
# +----+----------+----+----+----+-----+------------------+
# only showing top 5 rows

# %%
asc_df = df.sort(df.Date.asc()) #Sắp xếp các cột theo tứ tự tăng dần của thời gian

# %%
asc_df.show(5)
# Out:
# +---+----------+----+----+----+-----+----+
# |_c0|      Date|Open|High| Low|Close|Mean|
# +---+----------+----+----+----+-----+----+
# |  0|2000-07-28|0.72|0.72|0.72| 0.72|0.72|
# |  1|2000-07-31|0.72|0.72|0.72| 0.72|0.72|
# |  2|2000-08-02|0.74|0.74|0.74| 0.74|0.74|
# |  3|2000-08-04|0.75|0.75|0.75| 0.75|0.75|
# |  4|2000-08-07|0.76|0.76|0.76| 0.76|0.76|
# +---+----------+----+----+----+-----+----+
# only showing top 5 rows

# %%
from pyspark.sql.functions import year

df_test = asc_df.filter(year("Date") > 2024) #tách ra tập test là tập gồm thông tin của năm 2025

# %%
df_test.show(5)
# Out:
# +----+----------+----+----+----+-----+------------------+
# | _c0|      Date|Open|High| Low|Close|              Mean|
# +----+----------+----+----+----+-----+------------------+
# |5939|2025-01-02| 7.5| 7.5|7.33| 7.33|             7.415|
# |5940|2025-01-03|7.33|7.33|6.85| 6.85|              7.09|
# |5941|2025-01-06|6.86|6.97| 6.8|  6.8|             6.885|
# |5942|2025-01-07|6.85|6.91|6.72| 6.72|6.8149999999999995|
# |5943|2025-01-08|6.77|6.79|6.68| 6.79| 6.734999999999999|
# +----+----------+----+----+----+-----+------------------+
# only showing top 5 rows

# %%
df_train = asc_df.subtract(df_test)   #tách ra tập train
df_train.count()
# Out:
# 5939

# %%
df_train = df_train.sort(df_train.Date.asc())   #sắp xếp lại tập train
df_train.show(5)
# Out:
# +---+----------+----+----+----+-----+----+
# |_c0|      Date|Open|High| Low|Close|Mean|
# +---+----------+----+----+----+-----+----+
# |  0|2000-07-28|0.72|0.72|0.72| 0.72|0.72|
# |  1|2000-07-31|0.72|0.72|0.72| 0.72|0.72|
# |  2|2000-08-02|0.74|0.74|0.74| 0.74|0.74|
# |  3|2000-08-04|0.75|0.75|0.75| 0.75|0.75|
# |  4|2000-08-07|0.76|0.76|0.76| 0.76|0.76|
# +---+----------+----+----+----+-----+----+
# only showing top 5 rows

# %%
dataset_train = df_train.toPandas()

# %%
# !pip install tensorflow

# %%
# Import những thư viện cần thiết
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os.path
from os import path
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# Thuc hien scale du lieu gia ve khoang 0,1
training_set = dataset_train.iloc[:, 6:7].values
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

# %% [markdown]
# Tạo dữ liệu train, X = 60 time steps, Y =  1 time step, có nghĩa lấy dữ liệu của 60 ngày trước để dự đoán cho ngày tiếp theo hay có thể hiểu là lấy 60 ngày trước làm đầu vào, và đầu ra của mô hình sẽ là ngày tiếp theo

# %%
# Tạo dữ liệu train 
X_train = []
y_train = []
no_of_sample = len(training_set)

for i in range(60, no_of_sample):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
# Xây dựng model LSTM
regressor = Sequential()
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))
regressor.add(Dense(units = 1))
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
# Out:
# /opt/conda/envs/stock_price/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Nếu tồn tại model thì load lại nếu không thì thực hiện train 
if path.exists("mymodel.h5"):
    regressor.load_weights("mymodel.h5")
else:
    regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)
    regressor.save("mymodel.h5")
# Out:
# Epoch 1/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 18s 77ms/step - loss: 0.0034
# Epoch 2/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 62ms/step - loss: 0.0016
# Epoch 3/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 77ms/step - loss: 0.0014
# Epoch 4/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 63ms/step - loss: 0.0012
# Epoch 5/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 77ms/step - loss: 0.0010
# Epoch 6/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - loss: 9.5737e-04
# Epoch 7/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - loss: 8.5974e-04
# Epoch 8/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 77ms/step - loss: 8.3588e-04
# Epoch 9/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - loss: 8.9360e-04
# Epoch 10/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 78ms/step - loss: 6.8157e-04
# Epoch 11/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 7.3638e-04
# Epoch 12/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 75ms/step - loss: 6.8964e-04
# Epoch 13/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - loss: 5.9161e-04
# Epoch 14/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 78ms/step - loss: 6.0015e-04
# Epoch 15/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 6.8292e-04
# Epoch 16/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 77ms/step - loss: 6.5157e-04
# Epoch 17/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 63ms/step - loss: 5.7747e-04
# Epoch 18/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - loss: 5.0194e-04
# Epoch 19/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - loss: 5.3657e-04
# Epoch 20/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 75ms/step - loss: 5.4186e-04
# Epoch 21/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 62ms/step - loss: 5.1536e-04
# Epoch 22/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 75ms/step - loss: 5.0476e-04
# Epoch 23/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - loss: 4.7264e-04
# Epoch 24/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 63ms/step - loss: 5.0574e-04
# Epoch 25/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 75ms/step - loss: 5.4425e-04
# Epoch 26/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 63ms/step - loss: 4.8731e-04
# Epoch 27/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 77ms/step - loss: 4.6382e-04
# Epoch 28/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 63ms/step - loss: 4.5303e-04
# Epoch 29/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - loss: 4.7411e-04
# Epoch 30/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 63ms/step - loss: 4.1586e-04
# Epoch 31/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - loss: 4.5928e-04
# Epoch 32/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - loss: 4.9338e-04
# Epoch 33/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - loss: 4.0226e-04
# Epoch 34/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - loss: 4.0700e-04
# Epoch 35/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 75ms/step - loss: 4.1445e-04
# Epoch 36/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 75ms/step - loss: 3.9359e-04
# Epoch 37/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 63ms/step - loss: 4.2360e-04
# Epoch 38/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 77ms/step - loss: 4.5873e-04
# Epoch 39/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 11s 60ms/step - loss: 4.4411e-04
# Epoch 40/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 74ms/step - loss: 3.9216e-04
# Epoch 41/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 62ms/step - loss: 3.9806e-04
# Epoch 42/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - loss: 4.0399e-04
# Epoch 43/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - loss: 3.8492e-04
# Epoch 44/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 75ms/step - loss: 4.0336e-04
# Epoch 45/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 3.9200e-04
# Epoch 46/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 78ms/step - loss: 3.6594e-04
# Epoch 47/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 4.1966e-04
# Epoch 48/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 77ms/step - loss: 3.9406e-04
# Epoch 49/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 3.8202e-04
# Epoch 50/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 74ms/step - loss: 4.2962e-04
# Epoch 51/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 13s 73ms/step - loss: 4.2257e-04
# Epoch 52/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 11s 60ms/step - loss: 4.0745e-04
# Epoch 53/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 74ms/step - loss: 3.6011e-04
# Epoch 54/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - loss: 3.7576e-04
# Epoch 55/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 74ms/step - loss: 3.6605e-04
# Epoch 56/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - loss: 3.7792e-04
# Epoch 57/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 73ms/step - loss: 3.7792e-04
# Epoch 58/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - loss: 3.7009e-04
# Epoch 59/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - loss: 3.3691e-04
# Epoch 60/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 62ms/step - loss: 3.7396e-04
# Epoch 61/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 75ms/step - loss: 3.3977e-04
# Epoch 62/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - loss: 3.2849e-04
# Epoch 63/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 62ms/step - loss: 3.5752e-04
# Epoch 64/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 75ms/step - loss: 3.4887e-04
# Epoch 65/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - loss: 3.8472e-04
# Epoch 66/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 75ms/step - loss: 3.5733e-04
# Epoch 67/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 63ms/step - loss: 3.6674e-04
# Epoch 68/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - loss: 3.3849e-04
# Epoch 69/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - loss: 3.3147e-04
# Epoch 70/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 75ms/step - loss: 2.8073e-04
# Epoch 71/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - loss: 3.7018e-04
# Epoch 72/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 75ms/step - loss: 3.6190e-04
# Epoch 73/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - loss: 3.3496e-04
# Epoch 74/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 13s 71ms/step - loss: 3.5978e-04
# Epoch 75/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 74ms/step - loss: 3.1019e-04
# Epoch 76/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 11s 60ms/step - loss: 3.1487e-04
# Epoch 77/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 13s 72ms/step - loss: 3.3148e-04
# Epoch 78/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - loss: 2.8564e-04
# Epoch 79/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 13s 73ms/step - loss: 3.2669e-04
# Epoch 80/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 11s 59ms/step - loss: 3.1833e-04
# Epoch 81/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 75ms/step - loss: 3.4074e-04
# Epoch 82/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 3.4513e-04
# Epoch 83/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 78ms/step - loss: 3.3746e-04
# Epoch 84/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 3.2763e-04
# Epoch 85/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - loss: 3.2751e-04
# Epoch 86/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 3.3596e-04
# Epoch 87/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 78ms/step - loss: 3.0228e-04
# Epoch 88/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 78ms/step - loss: 3.3185e-04
# Epoch 89/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - loss: 2.8391e-04
# Epoch 90/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - loss: 3.1374e-04
# Epoch 91/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 63ms/step - loss: 3.0553e-04
# Epoch 92/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 77ms/step - loss: 2.9810e-04
# Epoch 93/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 63ms/step - loss: 3.2673e-04
# Epoch 94/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 77ms/step - loss: 3.1101e-04
# Epoch 95/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - loss: 3.1794e-04
# Epoch 96/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 77ms/step - loss: 3.0812e-04
# Epoch 97/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - loss: 3.0336e-04
# Epoch 98/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 78ms/step - loss: 3.2054e-04
# Epoch 99/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - loss: 2.7550e-04
# Epoch 100/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - loss: 3.1941e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
dataset_test = df_test.toPandas()
real_stock_price = dataset_test.iloc[:, 6:7].values

# %%
# Tiến hành dự đoán 
dataset_total = pd.concat((dataset_train['Mean'], dataset_test['Mean']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)

X_test = []
no_of_sample = len(inputs)

for i in range(60, no_of_sample):
    X_test.append(inputs[i-60:i, 0])

X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step

# %%
# Ve bieu do gia that va gia du doan
plt.figure(figsize=(16,9))
plt.plot(real_stock_price, color = 'red', label = 'Real SAM Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted SAM Stock Price')
plt.title('SAM Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('SAM Stock Price')
plt.legend()
plt.show()

# %%
spark.stop()

# %%
Image("spark_st.png")
